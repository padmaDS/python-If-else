# %%
l = [1,2,3,4,5, "keziya" , 45.67, True]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[5]
# Out:
# 'keziya'

# %%
l[-1]
# Out:
# True

# %%
l[7]
# Out:
# True

# %%
len(l)
# Out:
# 8

# %%
l[0:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
l[::-1]
# Out:
# [True, 45.67, 'nithin', 5, 4, 3, 2, 1]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
l[0:100:2]
# Out:
# [1, 3, 5, 45.67]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
l[0:8:-1]
# Out:
# []

# %%
l[:3]
# Out:
# [1, 2, 3]

# %%
l + ["varshith"]
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True, 'varshith']

# %%
l * 2
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True, 1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
60 in l
# Out:
# False

# %%
2 in l
# Out:
# True

# %%
max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 max(l)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
l1 = [3,4,5,6,6]

# %%
max(l1)
# Out:
# 6

# %%
min(l1)
# Out:
# 3

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
l2 = ["aimnxt" , "datascience" , "Hyderabad"]

# %%
max(l2)
# Out:
# 'datascience'

# %%
min(l2)
# Out:
# 'Hyderabad'

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True]

# %%
l.append("varshith")

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'keziya', 45.67, True, 'varshith']

# %%
l.append([1,2,3,4])

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'nithin', 45.67, True, 'harsha', [1, 2, 3, 4]]

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 4, 5, 'keziya', 45.67]

# %%
l.pop()
# Out:
# 45.67

# %%
l
# Out:
# [2, 3, 4, 5, 'keziya']

# %%
l.append("varshith")

# %%
l
# Out:
# [2, 3, 4, 5, 'keziya', 'varshith']

# %%
l.reverse()

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2]

# %%
l[::-1]
# Out:
# [2, 3, 4, 5, 'keziya', 'varshith']

# %%
l = l[::-1]

# %%
l
# Out:
# [2, 3, 4, 5, 'keziya', 'varshith']

# %%
l.reverse()

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2]

# %%
l.append ([1,2,3,4])

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l1
# Out:
# [3, 4, 5, 6, 6]

# %%
l1.sort()

# %%
l1
# Out:
# [3, 4, 5, 6, 6]

# %%
l3 = [8,98,34,23,1,0]

# %%
l3.sort()

# %%
l3
# Out:
# [0, 1, 8, 23, 34, 98]

# %%
l3.sort(reverse = True)

# %%
l3
# Out:
# [98, 34, 23, 8, 1, 0]

# %%
l1 = [2,3,4]
l2 = [6,7,8]
l3 = [3,2,4]

# %%
l4 = [l1,l2,l3]

# %%
l4
# Out:
# [[2, 3, 4], [6, 7, 8], [3, 2, 4]]

# %%
l4[1]
# Out:
# [6, 7, 8]

# %%
l4[2]
# Out:
# [3, 2, 4]

# %%
l4[2][0]
# Out:
# 3

# %%
l4[1][1]
# Out:
# 7

# %%
l4[0][2]
# Out:
# 4

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.count(2)
# Out:
# 1

# %%
l.count(5)
# Out:
# 1

# %%
l5 = [3,4,5,3,3,3]

# %%
l5.count(3)
# Out:
# 4

# %%
l1=[1,2,3]
l2=[4,5,6]
l3=[7,8,9]

# %%
l4 = [l1, l2, l3]

# %%
l4
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
l4.count(3)
# Out:
# 0

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.append("aimnxt")

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4], 'aimnxt']

# %%
l.append([4,56, "chakresh"])

# %%
l
# Out:
# ['varshith', 'keziya', 5, 4, 3, 2, [1, 2, 3, 4], 'aimnxt', [4, 56, 'chakresh']]

# %%
l.extend("shiva")

# %%
l
# Out:
# ['varshith',
#  'keziya',
#  5,
#  4,
#  3,
#  2,
#  [1, 2, 3, 4],
#  'aimnxt',
#  [4, 56, 'chakresh'],
#  's',
#  'h',
#  'i',
#  'v',
#  'a']

# %%
l6 = [1,2,3]

# %%
l6.append([4,5,6])

# %%
l6
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l6.append("aimnxt")

# %%
l6
# Out:
# [1, 2, 3, [4, 5, 6], 'aimnxt']

# %%
l6.extend(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 l6.extend(45)
#
# TypeError: 'int' object is not iterable

# %%
l6
# Out:
# [1, 2, 3, [4, 5, 6], 'aimnxt']

# %%
l6.extend([56,34,21])

# %%
l6
# Out:
# [1, 2, 3, [4, 5, 6], 'aimnxt', 56, 34, 21]

# %%
l6[3]
# Out:
# [4, 5, 6]

# %%
l6.index(1)
# Out:
# 0

# %%
l6.index("aimnxt")
# Out:
# 4

# %%
l7  = [1,2,3,4,55,6,6,7]

# %%
l7.index(6)
# Out:
# 5

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l.insert(1, [1,2,34])

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 5]

# %%
l.insert(5,"aimnxt")

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 'aimnxt', 5]

# %%
l.pop()
# Out:
# 5

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 'aimnxt']

# %%
l.pop(2)
# Out:
# 2

# %%
l
# Out:
# [1, [1, 2, 34], 3, 4, 'aimnxt']

# %%
l.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 l.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(4)

# %%
l
# Out:
# [1, [1, 2, 34], 3, 'aimnxt']

# %%
l.remove(3)

# %%
l
# Out:
# [1, [1, 2, 34], 'aimnxt']

# %%
l = [1,2,3,4]

# %%
l[2]
# Out:
# 3

# %%
l[2] = "aimnxt"

# %%
l
# Out:
# [1, 2, 'aimnxt', 4]

# %%
s = "aimnxt"

# %%
s[2] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 s[2] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %%
t = (4,5,6,7,"aimnxt" ,45.67, True)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 4

# %%
t[-1]
# Out:
# True

# %%
t[0:4]
# Out:
# (4, 5, 6, 7)

# %%
t
# Out:
# (4, 5, 6, 7, 'aimnxt', 45.67, True)

# %%
t[0:6:2]
# Out:
# (4, 6, 'aimnxt')

# %%
t[0:4:-1]
# Out:
# ()

# %%
t[::-1]
# Out:
# (True, 45.67, 'aimnxt', 7, 6, 5, 4)

# %%
l = [1,2,3,456,78]

# %%
l[2] = "kumar"

# %%
l
# Out:
# [1, 2, 'kumar', 456, 78]

# %%
t
# Out:
# (4, 5, 6, 7, 'aimnxt', 45.67, True)

# %%
t[2] = "rahul"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[263], line 1
# ----> 1 t[2] = "rahul"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (3,4,5,6)

# %%
t
# Out:
# (4, 5, 6, 7, 'aimnxt', 45.67, True)

# %%
t + t1
# Out:
# (4, 5, 6, 7, 'aimnxt', 45.67, True, 3, 4, 5, 6)

# %%
t.count(3)
# Out:
# 0

# %%
t.count(4)
# Out:
# 1

# %%
t.index(5)
# Out:
# 1

# %%
t.index("aimnxt")
# Out:
# 4

# %%
t = t+t1

# %%
t
# Out:
# (4, 5, 6, 7, 'aimnxt', 45.67, True, 3, 4, 5, 6)

# %%
t = (3,4,56,7, "aimnxt")

# %%
type(t)
# Out:
# tuple

# %%
t2 = list(t)

# %%
t2
# Out:
# [3, 4, 56, 7, 'aimnxt']

# %%
type(t2)
# Out:
# list

# %%
tuple(t2)
# Out:
# (3, 4, 56, 7, 'aimnxt')

# %%
t3 = str(t2)

# %%
t3
# Out:
# "[3, 4, 56, 7, 'aimnxt']"

# %%
type(t3)
# Out:
# str

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {1}

# %%
type(d1)
# Out:
# set

# %%
d2 = { 'key1' : "value"  , 234 : "xyz" , "name" : "sudh" , "no" : 34324345 }

# %%
type(d2)
# Out:
# dict

# %%
d2['name']
# Out:
# 'sudh'

# %%
d2['no']
# Out:
# 34324345

# %%
d3 = {'name': "sudh" , 'tech' :["python" , "ML" , "DL" , "NLP","CV" , "Big data" , "data analytics"]}

# %%
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ML', 'DL', 'NLP', 'CV', 'Big data', 'data analytics']}

# %%
"python" in d3['tech']
# Out:
# True

# %%
d4 = {"name" :"iNeuron" , "contact_info" : 345345 , "name":"sudh"}

# %%
d4
# Out:
# {'name': 'sudh', 'contact_info': 345345}

# %%
d4["name1"] = "xyz"

# %%
d4
# Out:
# {'name': 'xyz', 'contact_info': 345345, 'k1': 'xyz', 'name1': 'xyz'}

# %%
d4['k2'] = d2

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d4
# Out:
# {'name': 'xyz',
#  'contact_info': 345345,
#  'k1': 'xyz',
#  'name1': 'xyz',
#  'k2': {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}}

# %%
d4['k2']['no']
# Out:
# 34324345

# %%
d5 = {_: "sdfsd"}

# %%
d5[_]
# Out:
# 'sdfsd'

# %%
d6 = {(1,2,34) : "fsdfs"}

# %%
d6[(1,2,34)]
# Out:
# 'fsdfs'

# %%
d7 = {[1,2,3,4] : "fasdfasfas"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/3610375228.py in <module>
# ----> 1 d7 = {[1,2,3,4] : "fasdfasfas"}
#
# TypeError: unhashable type: 'list'

# %%
d8 = {{3:4} : "fsdfs"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/2992907961.py in <module>
# ----> 1 d8 = {{3:4} : "fsdfs"}
#
# TypeError: unhashable type: 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ML', 'DL', 'NLP', 'CV', 'Big data', 'data analytics']}

# %%
d2 +d3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/1153330958.py in <module>
# ----> 1 d2 +d3
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d2.keys()
# Out:
# dict_keys(['key1', 234, 'name', 'no'])

# %%
d2.values()
# Out:
# dict_values(['value', 'xyz', 'sudh', 34324345])

# %%
d2.items()
# Out:
# dict_items([('key1', 'value'), (234, 'xyz'), ('name', 'sudh'), ('no', 34324345)])

# %%
s = {3,4,5,6,7,8}

# %%
type(s)
# Out:
# set

# %%
s1 = {3,4,4,5,6,6,7,7,8,8,9,9,0,0,0}

# %%
s1
# Out:
# {0, 3, 4, 5, 6, 7, 8, 9}

# %%
s2 = { 3245,4545,6456,5645,675,6234,345}

# %%
s2
# Out:
# {345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s3 = {"sudh" , 324,34,12,645,12,5,'b' , '6'}

# %%
s3
# Out:
# {12, 324, 34, 5, '6', 645, 'b', 'sudh'}

# %%
s3[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/397937684.py in <module>
# ----> 1 s3[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list(s3)
# Out:
# ['b', 34, 324, 5, 645, '6', 'sudh', 12]

# %%
tuple(s3)
# Out:
# ('b', 34, 324, 5, 645, '6', 'sudh', 12)

# %%
 l = [2,3,4,5656,7,6,7,7,7,77,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7]

# %%
l = list(set(l))

# %%
l
# Out:
# [2, 3, 4, 6, 7, 77, 5656]

# %%
s2
# Out:
# {345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s2.add(34)

# %%
s2
# Out:
# {34, 345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s2.add([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/1499940319.py in <module>
# ----> 1 s2.add([1,2,3,4,5])
#
# TypeError: unhashable type: 'list'

# %%
s = {(1,2,3,4,5) , 3,4,45,65,6}

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s1 = {[1,2,3,4] , 345 ,345}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/1121764547.py in <module>
# ----> 1 s1 = {[1,2,3,4] , 345 ,345}
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s.remove(35345)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28700/3668842940.py in <module>
# ----> 1 s.remove(35345)
#
# KeyError: 35345

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 4, 45, 6, 65}

# %%
s.discard(3452646)

# %%
s.pop()
# Out:
# 65

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 45, 6}

# %%
type(s)
# Out:
# set

# %%
l = list(s)

# %%
l
# Out:
# [6, (1, 2, 3, 4, 5), 45]

# %%
set(l)
# Out:
# {(1, 2, 3, 4, 5), 45, 6}

# %%
str
list 
tuple
dict
set

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d2["key4"] = "sdfsf"

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345, 'key4': 'sdfsf'}

# %%
d2["key1"]  = "ineuron"

# %%
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf'}

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [9, 8, 7]

# %%
#Questions 

l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]
1 . Try to reverse a list 
2. try to access 234 out of this list 
3 . try to access 456 
4 . Try to extract only a list collection form list l 
5 . Try to extract "sudh"
6 . Try to list all the key in dict element avaible in list 
7 . Try to extract all the value element form dict available in list

# %%
s = "surya"
s1 = "su"

# %%
s+s1
# Out:
# 'suryasu'

# %%
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf'}

# %%
d2.fromkeys("k1")
# Out:
# {'k': None, '1': None}

# %%
d2['k'] = "sudh"

# %%
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf',
#  'k': 'sudh'}

# %%
side1 = float(input("Enter first side of triangle"))
side2 = float(input("Enter second side of triangle"))
side3 = float(input("Enter third side of triangle"))
s = (side1+side2+side3)/2
ar = (s*(s-side1)*(s-side2)*(s-side3)) ** 0.5
print("Area of the triangle is, ", ar)
# Out:
# Enter first side of triangle34
# Enter second side of triangle56
# Enter third side of triangle34
# Area of the triangle is,  540.0444426156055

# %%
l = [1,2,3,4,5]

# %%
l.insert(-1 , "sudh")

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 5]

# %%
for i in l:
    if type(i)==list:
        print(i)
    else:
        if type(i)==dict:
            if type(i.values()==list):
                for j in i.values():
                    if type(j)==list:
                        print(list(j))

# %%
d6 = {_ : "fdsdf"}

# %%
d6
# Out:
# {'': 'fdsdf'}

# %%
t = ( 4,5,6)

# %%
t1 =( 6 )

# %%
type(t1)
# Out:
# int

# %%
#Question
D_NEW = {'name':'Vishnu','title':'Data Analyst','course':'FSDS'}
D_NEW['key1'] = D_NEW
print(D_NEW['name'])
print(D_NEW['key1'])
# Out:
# Vishnu
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
print(D_NEW['name'])
print(D_NEW['key1'])
# Out:
# Vishnu
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
D_NEW
# Out:
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
t1=(3,5,67.8,789,'876dfghj')
t=t+t1
type(t)
t.count(3)
t2=list(t)
t2
tuple(t2)
str(t2)
tuple(t2)
type(t2)
# Out:
# list

# %%
s = {3,4,5,6,7,7}

# %%
s
# Out:
# {3, 4, 5, 6, 7}

# %%
list(s)[0]
# Out:
# 3

# %%
round(34.5656567 , 2)
# Out:
# 34.57

# %%
###### MY QUESTIONS #####
d4={"name":"iNeuron", "contact_info":34345,"name":"rupe"}
d4['loc']='Calgary'
d4['check'] = d4
#### LOOP ####
print(d4['check'])
#### TYPE ####
print(d4.keys())
print(d4.items())
print(type(d2.keys()))
print(type(d2.items()))
#### SIGNATURE #########
n=[4, 5, 7, 9, 2, 3, 4, 5, 2, 1, 9, 6, 7, 0]
n.pop()
n.sort()

# %%
d2 = { "k1" :"fsdfs" , "k2 " : [4,5,56]}

# %%
l = d2.keys()

# %%
list(l)[0]
# Out:
# 'k1'

# %%
n=[4, 5, 7, 9, 2, 3, 4, 5, 2, 1, 9, 6, 7, 0]
n.pop()
n.sort()

# %%
s = { 1,2,None, 3,4}

# %%
l = [3,4,5,6,7, [23,456,67,8,78,78], [345,56,87,8,98,9],(234,6657,6),{'key1':'sudh', 234:[]}]
umesh
1
l = [1,2,3,4,5,6,7,[11,22,33,44,55,66],111,222,333,'umesh']
l
1
l
[1, 2, 3, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']
3
1
l.remove(3)
l
1
l
[1, 2, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']
2
1
l.remove(2)
l
1
l
[1, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']

# %%
l = [10,2,3,4,5,6,7,[11,22,33,44,55,66],111,222,333,'umesh']

# %%
l.remove(10)

# %%
l
# Out:
# [2, 3, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']

# %%
l=[1,'a','d',[1,5,'asdf','zswe','aa',345],45,"dfg",['s','d',1,2,3],'k']
for i in l:
    if type(i) == list:
        for j in range(len(i)-1):
            print(i[j])
            while type(i[j]) == str:
                i.remove(i[j])
print(l)
# Out:
# 1
# 5
# asdf
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17348/1981221033.py in <module>
#       3     if type(i) == list:
#       4         for j in range(len(i)-1):
# ----> 5             print(i[j])
#       6             while type(i[j]) == str:
#       7                 i.remove(i[j])
#
# IndexError: list index out of range

# %%
def func():
    try:
        a = int(input("please enter a value :"))
        b = int(input("please enter b value :"))
        c = a/b
        print(c)
    except ValueError:
        print("values must be integers")
    except ZeroDivisionError:
        print("b value should not be zero")
    except TypeError:
        print("please enter the interger only not floating")

# %%
func()
# Out:
# please enter a value : -3
# please enter b value : 2
# -1.5

# %%
fun
